# %%
import requests
import pprint
pp = pprint.PrettyPrinter(indent=4)

# Using Petfinder API
# https://www.petfinder.com/developers/api-docs
# http://api.petfinder.com/my.method?key=12345&arg1=foo
# http://api.petfinder.com/breed.list?key=api_key&animal=cat&format=json
api_key= "31b8ef47be5499bd9c27bbc4be9068fc"
api_secret = "d5feca2097be49af4cf400b345fa8c36"

# Get request
# r = requests.get(f'https://api.nasa.gov/planetary/apod?date={date}&api_key={api_key}')
r = requests.get(f'http://api.petfinder.com/pet.getRandom?key={api_key}&animal=cat&output=full&format=json')
#print(r.status_code)
pp.pprint(r.json())
info = r.json()
# Out:
# {   '@encoding': 'iso-8859-1',
#     '@version': '1.0',
#     'petfinder': {   '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#                      '@xsi:noNamespaceSchemaLocation': 'http://api.petfinder.com/schemas/0.9/petfinder.xsd',
#                      'header': {   'status': {   'code': {'$t': '100'},
#                                                  'message': {}},
#                                    'timestamp': {'$t': '2019-01-04T20:24:39Z'},
#                                    'version': {'$t': '0.1'}},
#                      'pet': {   'age': {'$t': 'Senior'},
#                                 'animal': {'$t': 'Cat'},
#                                 'breeds': {   'breed': {   '$t': 'Domestic '
#                                                                  'Short Hair'}},
#                                 'contact': {   'address1': {   '$t': '5051 '
#                                                                      'Letterkenny '
#                                                                      'Road '
#                                                                      'West'},
#                                                'address2': {},
#                                                'city': {'$t': 'Chambersburg'},
#                                                'email': {   '$t': 'cvasadopt@cvas-pets.org'},
#                                                'fax': {},
#                                                'phone': {'$t': '717-263-5791'},
#                                                'state': {'$t': 'PA'},
#                                                'zip': {'$t': '17201'}},
#                                 'description': {   '$t': 'Chocolate Murray was '
#                                                          'brought into the '
#                                                          'shelter as a stray '
#                                                          'that was covered in '
#                                                          'fleas and had a bad '
#                                                          'ear infection, we '
#                                                          'were surprised when '
#                                                          'we scanned him on '
#                                                          'intake that he had '
#                                                          'been adopted from us '
#                                                          'as a kitten! We '
#                                                          'tried to contact his '
#                                                          'adopters but were '
#                                                          'not successful in '
#                                                          'reaching them or '
#                                                          'finding them, the '
#                                                          'information was out '
#                                                          'of date. Chocolate '
#                                                          'Murray is a sweet '
#                                                          'boy and has had his '
#                                                          'fleas and ears '
#                                                          'treated. He is now '
#                                                          'looking for a home '
#                                                          'to spend his golden '
#                                                          'years in and not '
#                                                          'have to worry about '
#                                                          'being in the streets '
#                                                          'ever again. '
#                                                          'Chocolate Murray was '
#                                                          'declawed at some '
#                                                          'point after he was '
#                                                          'adopted the first '
#                                                          'time. Murray would '
#                                                          'love to meet you and '
#                                                          'show you what a '
#                                                          'sweet boy he is!'},
#                                 'id': {'$t': '42766280'},
#                                 'lastUpdate': {'$t': '2018-09-15T12:53:37Z'},
#                                 'media': {   'photos': {   'photo': [   {   '$t': 'http://photos.petfinder.com/photos/pets/42766280/1/?bust=1537286115&width=60&-pnt.jpg',
#                                                                             '@id': '1',
#                                                                             '@size': 'pnt'},
#                                                                         {   '$t': 'http://photos.petfinder.com/photos/pets/42766280/1/?bust=1537286115&width=95&-fpm.jpg',
#                                                                             '@id': '1',
#                                                                             '@size': 'fpm'},
#                                                                         {   '$t': 'http://photos.petfinder.com/photos/pets/42766280/1/?bust=1537286115&width=500&-x.jpg',
#                                                                             '@id': '1',
#                                                                             '@size': 'x'},
#                                                                         {   '$t': 'http://photos.petfinder.com/photos/pets/42766280/1/?bust=1537286115&width=300&-pn.jpg',
#                                                                             '@id': '1',
#                                                                             '@size': 'pn'},
#                                                                         {   '$t': 'http://photos.petfinder.com/photos/pets/42766280/1/?bust=1537286115&width=50&-t.jpg',
#                                                                             '@id': '1',
#                                                                             '@size': 't'}]}},
#                                 'mix': {'$t': 'yes'},
#                                 'name': {'$t': 'Chocolate Murray'},
#                                 'options': {   'option': [   {'$t': 'noClaws'},
#                                                              {'$t': 'altered'},
#                                                              {'$t': 'hasShots'},
#                                                              {   '$t': 'housetrained'}]},
#                                 'sex': {'$t': 'M'},
#                                 'shelterId': {'$t': 'PA78'},
#                                 'shelterPetId': {'$t': '45726'},
#                                 'size': {'$t': 'L'},
#                                 'status': {'$t': 'A'}}}}
